# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
calibrate = pd.read_csv('static.csv')
calibrate.columns = 'timestamp acce ax ay az gyro gx gy gz mag mx my mz dt'.split(' ')

# %%
plt.plot(calibrate.timestamp, calibrate.ax)

# %%
plt.plot(calibrate.timestamp, calibrate.ay)

# %% [markdown]
# print(calibrate.ax.max(), calibrate.ax.mean(), calibrate.ax.std())

# %%
print(calibrate.ay.max(), calibrate.ay.mean(), calibrate.ay.std())
# Out:
# -0.091 -0.10577028451001054 0.00499408109826173

# %%
ay = np.array(calibrate.ay)
t = np.array(calibrate.timestamp)

# %%
print(ay.shape, t.shape)
# Out:
# (949,) (949,)

# %%
out = np.fft.fft(ay)

# %%
#t = np.arange(256)
sp = np.fft.fft(ay)
freq = np.fft.fftfreq(t.shape[-1])
plt.plot(sp.imag, sp.real)

# %%
np.sin(t).shape
# Out:
# (1815,)
