# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
dataset = pd.read_csv('quarternion_log.csv')

# %%
dataset.columns = 'qx qy qz qw'.split(' ')

# %%
dataset.head()
# Out:
#          qx        qy        qz        qw
# 0  0.998312  0.000040  0.000041 -0.000025
# 1  0.998312 -0.000482 -0.000302 -0.000778
# 2 -0.998312  0.000907 -0.000360  0.000169
# 3  0.998312 -0.000331  0.000725  0.000580
# 4  0.998312  0.000140  0.000078 -0.000021

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484 entries, 0 to 483
# Data columns (total 4 columns):
# qx    484 non-null float64
# qy    484 non-null float64
# qz    484 non-null float64
# qw    484 non-null float64
# dtypes: float64(4)
# memory usage: 15.2 KB

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot(dataset.qx, dataset.qy, dataset.qz)
